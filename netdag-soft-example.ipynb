# %%
models = {}

# %%
from IPython.display import Image

Image(filename='simple-task-graph.xml.gz_task-graph.png')

# %%
import netdag
import importlib

importlib.reload(netdag)

g = netdag.load_graph('simple-task-graph.xml.gz')
assert(netdag.is_DAG(g))
network = {'A': 1, 'B': 1, 'C': 1, 'D': 1, 'GAMMA': 1, 'LAMBDA': netdag.LAMBDA_SOFT}
model = netdag.get_makespan_optimal_soft_schedule(g, network)
zeta, chi, duration, label = model
models['simple-9'] = model
print('zeta', zeta)
print('chi', chi)
print('duration', duration)
print('label', label)
# Out:
# *computing optimal soft real-time schedule via MIP*
# 	instantiating symvars...
# 	generating constraint clauses...
# 		domain
# 		one_hot
# 		CFOP
# 		task_partitioning_by_round
# 		round_empty
# 		durations
# 		label_to_delta
# 		chi_to_delta
# 		binary_mult_linearization
# 		order
# 		exclusion
# 		soft
# 		deadline
# 	sending to solver...
# CPXPARAM_Read_DataCheck                          1
# Warning:  Non-integral bounds for integer variables rounded.
# Tried aggregator 2 times.
# MIP Presolve eliminated 39498 rows and 4027 columns.
# MIP Presolve modified 1459 coefficients.
# Aggregator did 4 substitutions.
# Reduced MIP has 29809 rows, 10181 columns, and 72543 nonzeros.
# Reduced MIP has 373 binaries, 39 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.13 sec. (141.69 ticks)
# Probing fixed 991 vars, tightened 37 bounds.
# Probing changed sense of 57 constraints.
# Probing time = 1.19 sec. (946.32 ticks)
# Tried aggregator 1 time.
# MIP Presolve eliminated 2975 rows and 1028 columns.
# MIP Presolve modified 526 coefficients.
# Reduced MIP has 26834 rows, 9146 columns, and 65636 nonzeros.
# Reduced MIP has 7883 binaries, 33 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.14 sec. (153.45 ticks)
# Probing fixed 0 vars, tightened 6 bounds.
# Probing time = 0.23 sec. (101.50 ticks)
# Tried aggregator 1 time.
# MIP Presolve eliminated 38 rows and 14 columns.
# MIP Presolve modified 1 coefficients.
# Reduced MIP has 26796 rows, 9132 columns, and 65556 nonzeros.
# Reduced MIP has 7879 binaries, 33 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.13 sec. (129.11 ticks)
# Probing fixed 0 vars, tightened 2 bounds.
# Probing time = 0.07 sec. (17.59 ticks)
# Clique table members: 42975.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 12 threads.
# Root relaxation solution time = 0.31 sec. (234.15 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
#       0     0       98.0000   239                     98.0000     1004
#       0     0       99.0000   243                   Cuts: 185     2024
#       0     0       99.0000   158                   Cuts: 141     2542
#       0     0       99.0000   121                   Cuts: 137     2752
#       0     0       99.0000   192                   Cuts: 194     3331
#       0     0      100.0000   226                    Cuts: 66     4519
#       0     0      100.0000   184                   Cuts: 252     4760
#       0     0      100.0000   174                   Cuts: 209     5190
#       0     0      100.0000   172                   Cuts: 132     5348
#       0     2      100.0000   172                    100.0000     5348
# Elapsed time = 17.69 sec. (12288.88 ticks, tree = 0.02 MB, solutions = 0)
#       2     3      120.0000   209                    100.0000     6552
#       6     8      120.0000   188                    100.0000     8564
#      12    12      172.9938   282                    100.0000     9695
#      20    17      218.2211   256                    100.4231    12407
#      31    28      216.3366   298                    100.4231    29464
#      49    39      285.8259   211                    100.4231    37362
#      78    42      220.5167   325                    111.0000    38575
#     108    71      426.1192   187                    111.0000    58338
#     140    80    infeasible                          111.0000    65936
#     195   127    infeasible                          120.0000    91807
# Elapsed time = 134.44 sec. (79625.86 ticks, tree = 8.15 MB, solutions = 4)
#    7137   373      202.1404   392      478.0000      253.8352  1107807   46.90%
#    7201   375      220.5194   266      478.0000      253.8352  1115572   46.90%
#    7261   382      252.6581   336      478.0000      253.8352  1144037   46.90%
#    7324   389      214.3130   210      478.0000      253.8352  1164858   46.90%
#    7439   400      318.5406   230      478.0000      253.8352  1170906   46.90%
#    7769   398      326.2858   190      478.0000      253.8352  1168730   46.90%
#    8142   488      330.7599   167      478.0000      253.8352  1232969   46.90%
#    8563   521      475.0000    59      478.0000      253.8352  1255378   46.90%
#    9057   666    infeasible            478.0000      253.8352  1363963   46.90%
#    9630   677      427.0944   187      478.0000      253.8352  1409239   46.90%
# Elapsed time = 155.71 sec. (89338.69 ticks, tree = 4.89 MB, solutions = 4)
#    9916   725      465.3096    73      478.0000      253.8352  1445329   46.90%
#   10076   729      311.7242   313      478.0000      253.8352  1487807   46.90%
#   10255   729        cutoff            478.0000      268.7230  1473780   43.78%
#   10454   700      477.0000     5      478.0000      296.5043  1501705   37.97%
#   10671   638      411.5220   240      478.0000      313.2236  1532578   34.47%
#   11152   529      474.1343    82      478.0000      325.4228  1560486   31.92%
#   12120   475      457.8600    59      478.0000      377.0686  1595097   21.12%
#   12794   347    infeasible            478.0000      459.3873  1604058    3.89%
#   13679   201      475.0000    62      478.0000      474.9812  1611783    0.63%
#
# GUB cover cuts applied:  7
# Clique cuts applied:  11
# Cover cuts applied:  16
# Implied bound cuts applied:  61
# Flow cuts applied:  29
# Mixed integer rounding cuts applied:  48
# Zero-half cuts applied:  115
# Lift and project cuts applied:  2
# Gomory fractional cuts applied:  7
#
# Root node processing (before b&c):
#   Real time             =   17.48 sec. (12144.71 ticks)
# Parallel b&c, 12 threads:
#   Real time             =  158.83 sec. (86242.67 ticks)
#   Sync time (average)   =   34.87 sec.
#   Wait time (average)   =    0.02 sec.
#                           ------------
# Total (root+branch&cut) =  176.31 sec. (98387.38 ticks)
# CPLEX Error  1217: No solution exists.
# 	solver returned optimal!
# zeta [ -0.   0.   0. 204. 110. 204. 348. 411. 478.   1.   2. 104. 183. 302.
#  405. 432.]
# chi [3. 5. 5. 4. 4. 4. 1. 1. 1. 6. 6. 5. 4. 1.]
# duration [ -0.   0. 101.  72.  97.  56.  20.]
# label [3. 3. 4. 5. 5. 6. 7.]

# %%
importlib.reload(netdag)

netdag.draw_schedule(g, model, 'simple-task-graph.xml.gz_schedule-soft.png')
Image(filename='simple-task-graph.xml.gz_schedule-soft.png')

# %%
from IPython.display import Image

Image(filename='complex-035-task-graph.xml.gz_task-graph.png')

# %%
import netdag
import importlib

importlib.reload(netdag)

g = netdag.load_graph('complex-035-task-graph.xml.gz')
assert(netdag.is_DAG(g))
network = {'A': 1, 'B': 1, 'C': 1, 'D': 1, 'GAMMA': 1, 'LAMBDA': netdag.LAMBDA_SOFT}
model = netdag.get_makespan_optimal_soft_schedule(g, network)
models['complex-035'] = model
zeta, chi, duration, label = model
print('zeta', zeta)
print('chi', chi)
print('duration', duration)
print('label', label)
